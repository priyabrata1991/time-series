# %%
import pandas as pd

# %%
df=pd.read_csv('corona.csv')

# %%
df.head()
# Out:
#          date   World  Afghanistan  Africa  Albania  Algeria  Andorra  Angola  \
# 0  2020-01-22   557.0          NaN     NaN      NaN      NaN      NaN     NaN
# 1  2020-01-23   655.0          NaN     NaN      NaN      NaN      NaN     NaN
# 2  2020-01-24   941.0          NaN     NaN      NaN      NaN      NaN     NaN
# 3  2020-01-25  1434.0          NaN     NaN      NaN      NaN      NaN     NaN
# 4  2020-01-26  2118.0          NaN     NaN      NaN      NaN      NaN     NaN
#
#    Antigua and Barbuda  Argentina  ...  Upper middle income  Uruguay  \
# 0                  NaN        NaN  ...                552.0      NaN
# 1                  NaN        NaN  ...                645.0      NaN
# 2                  NaN        NaN  ...                923.0      NaN
# 3                  NaN        NaN  ...               1411.0      NaN
# 4                  NaN        NaN  ...               2079.0      NaN
#
#    Uzbekistan  Vanuatu  Vatican  Venezuela  Vietnam  Yemen  Zambia  Zimbabwe
# ...

# %%
df.columns
# Out:
# Index(['date', 'World', 'Afghanistan', 'Africa', 'Albania', 'Algeria',
#        'Andorra', 'Angola', 'Antigua and Barbuda', 'Argentina',
#        ...
#        'Upper middle income', 'Uruguay', 'Uzbekistan', 'Vanuatu', 'Vatican',
#        'Venezuela', 'Vietnam', 'Yemen', 'Zambia', 'Zimbabwe'],
#       dtype='object', length=209)

# %%
pd.pandas.set_option('display.max_columns',None)

# %%
df.head()
# Out:
#          date   World  Afghanistan  Africa  Albania  Algeria  Andorra  Angola  \
# 0  2020-01-22   557.0          NaN     NaN      NaN      NaN      NaN     NaN
# 1  2020-01-23   655.0          NaN     NaN      NaN      NaN      NaN     NaN
# 2  2020-01-24   941.0          NaN     NaN      NaN      NaN      NaN     NaN
# 3  2020-01-25  1434.0          NaN     NaN      NaN      NaN      NaN     NaN
# 4  2020-01-26  2118.0          NaN     NaN      NaN      NaN      NaN     NaN
#
#    Antigua and Barbuda  Argentina  Armenia    Asia  Australia  Austria  \
# 0                  NaN        NaN      NaN   556.0        NaN      NaN
# 1                  NaN        NaN      NaN   654.0        NaN      NaN
# 2                  NaN        NaN      NaN   937.0        NaN      NaN
# 3                  NaN        NaN      NaN  1429.0        NaN      NaN
# 4                  NaN        NaN      NaN  2105.0        4.0      NaN
#
# ...

# %%
df.tail()
# Out:
# date
# 2021-11-23    34535763.0
# 2021-11-24    34544882.0
# 2021-11-25    34555431.0
# 2021-11-26    34563749.0
# 2021-11-27    34572523.0
# Name: India, dtype: float64

# %% [markdown]
# ### This data set contains no corona cases registered in every country in the world from 22 Jan 2020 to 27 Nov 2021
#
# ### I will use Indian data for prediction

# %%
df.dtypes
# Out:
# date            object
# World          float64
# Afghanistan    float64
# Africa         float64
# Albania        float64
#                 ...
# Venezuela      float64
# Vietnam        float64
# Yemen          float64
# Zambia         float64
# Zimbabwe       float64
# Length: 209, dtype: object

# %%
df['date']=pd.to_datetime(df.date)

# %%
df.dtypes
# Out:
# date           datetime64[ns]
# World                 float64
# Afghanistan           float64
# Africa                float64
# Albania               float64
#                     ...
# Venezuela             float64
# Vietnam               float64
# Yemen                 float64
# Zambia                float64
# Zimbabwe              float64
# Length: 209, dtype: object

# %%
df.head()
# Out:
#         date   World  Afghanistan  Africa  Albania  Algeria  Andorra  Angola  \
# 0 2020-01-22   557.0          NaN     NaN      NaN      NaN      NaN     NaN
# 1 2020-01-23   655.0          NaN     NaN      NaN      NaN      NaN     NaN
# 2 2020-01-24   941.0          NaN     NaN      NaN      NaN      NaN     NaN
# 3 2020-01-25  1434.0          NaN     NaN      NaN      NaN      NaN     NaN
# 4 2020-01-26  2118.0          NaN     NaN      NaN      NaN      NaN     NaN
#
#    Antigua and Barbuda  Argentina  Armenia    Asia  Australia  Austria  \
# 0                  NaN        NaN      NaN   556.0        NaN      NaN
# 1                  NaN        NaN      NaN   654.0        NaN      NaN
# 2                  NaN        NaN      NaN   937.0        NaN      NaN
# 3                  NaN        NaN      NaN  1429.0        NaN      NaN
# 4                  NaN        NaN      NaN  2105.0        4.0      NaN
#
#    Azerbaijan  Bahamas  Bahrain  Bangladesh  Barbados  Belarus  Belgium  \
# ...

# %%
df.set_index('date', inplace=True)

# %%
df=df.India

# %%
df=df[df.isnull()==False]

# %%
df.isnull().sum()
# Out:
# 0

# %%
df.tail()
# Out:
# date
# 2021-11-23    34535763.0
# 2021-11-24    34544882.0
# 2021-11-25    34555431.0
# 2021-11-26    34563749.0
# 2021-11-27    34572523.0
# Name: India, dtype: float64

# %% [markdown]
# ### I have set date column as index and extracted Indian data and discard rest of the data

# %%
import matplotlib.pyplot as plt

# %%
plt.figure(figsize=(15,6))
plt.plot(df)
plt.show()

# %% [markdown]
# ### This data contains total no of cases found till the same day I want no of new cases in each day for that I will subtact previous day  total cases from present day total cases

# %%
x=df[1:].values-df[:-1].values

# %%
df_new=pd.Series(x,index=df[1:].index)

# %%
df_new
# Out:
# date
# 2020-01-31        0.0
# 2020-02-01        0.0
# 2020-02-02        1.0
# 2020-02-03        1.0
# 2020-02-04        0.0
#                ...
# 2021-11-23     9283.0
# 2021-11-24     9119.0
# 2021-11-25    10549.0
# 2021-11-26     8318.0
# 2021-11-27     8774.0
# Length: 667, dtype: float64

# %%
plt.figure(figsize=(15,6))
plt.plot(df_new)
plt.show()

# %% [markdown]
# ### Now my data is showing no of new cases in each day
#
# ### I will use last 150 day data to build my model

# %%
plt.figure(figsize=(40,6))
plt.plot(df_new.tail(150),marker="+")
plt.show()

# %% [markdown]
# ### There is a seasonality of 7 day in the data and the data is not statonary

# %%
df_new2=df_new.tail(150).copy()

# %%
df_new2
# Out:
# date
# 2021-07-01    46617.0
# 2021-07-02    44111.0
# 2021-07-03    43071.0
# 2021-07-04    39796.0
# 2021-07-05    34703.0
#                ...
# 2021-11-23     9283.0
# 2021-11-24     9119.0
# 2021-11-25    10549.0
# 2021-11-26     8318.0
# 2021-11-27     8774.0
# Length: 150, dtype: float64

# %%
plt.figure(figsize=(25,6))
plt.plot(df_new2[1:].values-df_new2[:-1].values,marker="+")
plt.grid()

# %% [markdown]
# ### Taking a difference of one makes the data statonary

# %%
df_new2=pd.Series(df_new2[1:].values-df_new2[:-1].values, df_new2[1:].index)

# %%
df_new2
# Out:
# date
# 2021-07-02   -2506.0
# 2021-07-03   -1040.0
# 2021-07-04   -3275.0
# 2021-07-05   -5093.0
# 2021-07-06    9030.0
#                ...
# 2021-11-23    1704.0
# 2021-11-24    -164.0
# 2021-11-25    1430.0
# 2021-11-26   -2231.0
# 2021-11-27     456.0
# Length: 149, dtype: float64

# %%
from statsmodels.tsa.stattools import adfuller

# %%
adf=adfuller(df_new2.values,autolag='AIC')
print('p',adf[1])
# Out:
# p 1.8492486715078107e-07

# %% [markdown]
# ### P value is less them 0.05 Hence I fail to accept H0. Therefore my data is staticaly stable

# %%
from statsmodels.graphics.tsaplots import plot_acf, plot_pacf

# %%
plot_a=plot_acf(df_new2, lags=30)

# %% [markdown]
# ### There are 3 strong MA lags 0,1,7
#
# ### 7 is a strong seasonal MA lag

# %%
plot_b=plot_pacf(df_new2)

# %% [markdown]
# ### There are 8 srong AR lags 0,1,2,3,5,6,13,20 but no seasonal lag

# %%
import itertools
import warnings
warnings.filterwarnings('ignore')
import numpy as np

# %%
i=[0,1,2,3,5,6,13,20]
j=[0,1,7]

# %%
ij=itertools.product(i,j)

# %%
from statsmodels.tsa.arima_model import ARMA

# %%
x=[]
l=[]
for i in ij:
    x.append(i)
    try:
        MD=ARMA(df_new2,order=(i))
        result=MD.fit(disp=False)
        l.append(result.aic)
    except:
        l.append(np.nan)
        continue

# %%
plt.plot(l,marker="+")
plt.show()

# %%
x[15],l[15]
# Out:
# ((6, 0), 3043.9386419491275)

# %% [markdown]
# ## Final conclusion
#
# ### I will use SARIMAX because there is seasonality in the data
#
# ### order will be 6,1,0 I am taking I as 1 beacuse taking first difference makes the data statonary
#
# ### seasonal order will be 0,0,1,7 I am taking MA as 1 beacuse strong seasonal lag of 7

# %%
from datetime import timedelta

# %%
my_data=df_new.tail(150)

# %%
from statsmodels.tsa.statespace.sarimax import SARIMAX

# %%
test_data=my_data[60:]

# %% [markdown]
# ### I will use rolling window technic for prediction as it gives best predictions

# %%
roll_pred=pd.Series()
for i in test_data.index:
    train_data=my_data[:i - timedelta(days=1)]
    model=SARIMAX(train_data, order=(6,1,0), seasonal_order=(0,0,1,7))
    model_fit=model.fit()
    pred=model_fit.predict(i)
    roll_pred[i]=pred.loc[i]

# %%
plt.figure(figsize=(20,6))
plt.plot(test_data,color='g')
plt.plot(roll_pred,color='b')
plt.show()

# %%
plt.figure(figsize=(20,6))
plt.plot(roll_pred-test_data)
plt.axhline(y=0, linestyle="--", color='k')
plt.show()

# %% [markdown]
# ### The resudial error shows no pattern and mean of my resudial error is almost 0

# %%
(((abs((test_data-roll_pred)/test_data)).sum())/90)*100
# Out:
# 14.288925452341338

# %% [markdown]
# ### Mean Absolute Percentage Error is 14% which means my model is 86% accurate
